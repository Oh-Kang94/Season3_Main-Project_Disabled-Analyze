# %% [markdown]
# # 라이브러리

# %%
options(warn =-1, repr.plot.width=15, repr.plot.height=9)
# ## 패키지 설치
library(dplyr)
library(stringr)
library(ggplot2)
library(gridExtra)
library(scales)
library(randomForest)
library(lubridate)
library(caret)
library(e1071)
library(nnet)
library(class)

# %% [markdown]
# # 전처리

# %%
### .csv 불러오기
data <- read.csv("./data/refined_data_filtered_major5_subset.csv")

# %%
data
# Out:
#       취업일자   연령 장애유형 중증여부 근무지역
# 1     2020-01-01 65   시각장애 중증     경북 경산시
# 2     2020-01-01 61   시각장애 중증     경북 고령군
# 3     2020-01-01 53   시각장애 경증     경북 의성군
# 4     2020-01-01 64   시각장애 중증     경북 성주군
# 5     2020-01-01 53   시각장애 경증     경북 군위군
# 6     2020-01-01 60   시각장애 중증     경북 영천시
# 7     2020-02-01 63   시각장애 중증     경북 영덕군
# 8     2020-03-02 40   시각장애 중증     경북 포항시
# 9     2020-07-01 56   지체장애 중증     강원 횡성군
# 10    2020-01-01 62   시각장애 중증     강원 화천군
# 11    2020-01-01 40   지체장애 경증     강원 태백시
# 12    2020-01-01 76   시각장애 중증     강원 춘천시
# 13    2020-01-01 69   시각장애 중증     강원 횡성군
# 14    2020-01-01 66   시각장애 중증     강원 횡성군
# 15    2020-01-01 20   시각장애 중증     강원 화천군
# 16    2020-01-13 30   지적장애 경증     강원 평창군
# 17    2020-03-23 49   지체장애 중증     강원 홍천군
# 18    2020-01-01 40   시각장애 중증     강원 횡성군
# 19    2020-01-01 65   시각장애 중증     강원 춘천시
# 20    2020-01-01 68   시각장애 중증     전남 목포시
# 21    2020-06-01 57   지체장애 경증     전남 목포시
# 22    2020-01-01 59   지체장애 경증     충북 영동군
# 23    2020-01-01 42   지체장애 경증     충북 영동군
# 24    2020-01-01 37   청각장애 경증     충북 영동군
# 25    2020-01-01 75   지체장애 경증     충북 영동군
# 26    2020-01-01 40   지적장애 중증     충북 영동군
# 27    2020-01-01 22   지적장애 중증     충북 영동군
# 28    2020-01-01 51   지체장애 중증     충북 영동군
# 29    2020-01-01 40   지적장애 중증     충북 영동군
# 30    2020-01-01 23   지적장애 중증     충북 영동군
# ⋮     ⋮          ⋮    ⋮        ⋮        ⋮
# 24950 2020-01-01 23   지적장애 중증     서울 마포구
# 24951 2020-01-01 40   지적장애 중증     서울 마포구
# 24952 2020-01-01 37   지적장애 중증     서울 마포구
# 24953 2020-11-01 23   지적장애 중증     서울 종로구
# 24954 2020-09-01 28   지적장애 중증     서울 종로구
# 24955 2020-10-05 53   지체장애 경증     충남 서산시
# 24956 2020-12-02 60   청각장애 중증     대구 달서구
# 24957 2020-01-30 70   지체장애 경증     서울 광진구
# 24958 2020-12-18 58   지체장애 경증     전남 순천시
# 24959 2020-11-23 53   지체장애 경증     서울 구로구
# 24960 2020-12-01 40   청각장애 중증     대구 동구
# 24961 2020-12-01 25   청각장애 중증     대구 동구
# 24962 2020-12-01 49   청각장애 중증     대구 동구
# 24963 2020-12-01 51   청각장애 중증     대구 동구
# 24964 2020-12-01 50   청각장애 중증     대구 동구
# 24965 2020-12-01 37   청각장애 중증     대구 동구
# 24966 2020-12-01 51   청각장애 중증     대구 동구
# 24967 2020-12-01 54   청각장애 중증     대구 동구
# 24968 2020-11-20 25   지체장애 경증     경기 부천시
# 24969 2020-08-01 31   지적장애 중증     제주 제주시
# 24970 2020-08-01 25   지적장애 중증     제주 제주시
# 24971 2020-12-10 30   지체장애 경증     경기 수원시 영통구
# 24972 2020-11-20 68   지체장애 경증     충남 서산시
# 24973 2020-11-25 42   지체장애 경증     충남 당진시
# 24974 2020-06-29 38   지적장애 중증     광주 북구
# 24975 2020-12-01 33   정신장애 중증     경기 김포시
# 24976 2020-10-01 63   시각장애 경증     경기 광주시
# 24977 2020-12-14 59   지체장애 경증     충남 천안시 동남구
# 24978 2020-12-03 53   시각장애 경증     서울 구로구
# 24979 2020-12-21 24   청각장애 경증     서울 중구
#       취업직종대분류                          연령대 장애유형_중증여부 월
# 1     경영·행정·사무직                        5      시각장애-중증     1
# 2     경영·행정·사무직                        5      시각장애-중증     1
# 3     경영·행정·사무직                        4      시각장애-경증     1
# 4     경영·행정·사무직                        5      시각장애-중증     1
# 5     경영·행정·사무직                        4      시각장애-경증     1
# 6     경영·행정·사무직                        5      시각장애-중증     1
# 7     경영·행정·사무직                        5      시각장애-중증     2
# 8     보건·의료직                             3      시각장애-중증     3
# 9     보건·의료직                             4      지체장애-중증     7
# 10    보건·의료직                             5      시각장애-중증     1
# 11    보건·의료직                             3      지체장애-경증     1
# 12    전기·전자 설치·정비·생산직              6      시각장애-중증     1
# 13    보건·의료직                             5      시각장애-중증     1
# 14    보건·의료직                             5      시각장애-중증     1
# 15    보건·의료직                             1      시각장애-중증     1
# 16    사회복지·종교직                         2      지적장애-경증     1
# 17    사회복지·종교직                         3      지체장애-중증     3
# 18    보건·의료직                             3      시각장애-중증     1
# 19    보건·의료직                             5      시각장애-중증     1
# 20    보건·의료직                             5      시각장애-중증     1
# 21    청소 및 기타 개인서비스직               4      지체장애-경증     6
# 22    경영·행정·사무직                        4      지체장애-경증     1
# 23    경영·행정·사무직                        3      지체장애-경증     1
# 24    경영·행정·사무직                        2      청각장애-경증     1
# 25    경영·행정·사무직                        6      지체장애-경증     1
# 26    경영·행정·사무직                        3      지적장애-중증     1
# 27    경영·행정·사무직                        1      지적장애-중증     1
# 28    경영·행정·사무직                        4      지체장애-중증     1
# 29    경영·행정·사무직                        3      지적장애-중증     1
# 30    경영·행정·사무직                        1      지적장애-중증     1
# ⋮     ⋮                                       ⋮      ⋮                 ⋮
# 24950 경영·행정·사무직                        1      지적장애-중증      1
# 24951 경영·행정·사무직                        3      지적장애-중증      1
# 24952 경영·행정·사무직                        2      지적장애-중증      1
# 24953 영업·판매직                             1      지적장애-중증     11
# 24954 영업·판매직                             1      지적장애-중증      9
# 24955 기계 설치·정비·생산직                   4      지체장애-경증     10
# 24956 기계 설치·정비·생산직                   5      청각장애-중증     12
# 24957 인쇄·목재·공예 및 기타 설치·정비·생산직 6      지체장애-경증      1
# 24958 식품 가공·생산직                        4      지체장애-경증     12
# 24959 사회복지·종교직                         4      지체장애-경증     11
# 24960 인쇄·목재·공예 및 기타 설치·정비·생산직 3      청각장애-중증     12
# 24961 인쇄·목재·공예 및 기타 설치·정비·생산직 1      청각장애-중증     12
# 24962 인쇄·목재·공예 및 기타 설치·정비·생산직 3      청각장애-중증     12
# 24963 인쇄·목재·공예 및 기타 설치·정비·생산직 4      청각장애-중증     12
# 24964 인쇄·목재·공예 및 기타 설치·정비·생산직 4      청각장애-중증     12
# 24965 인쇄·목재·공예 및 기타 설치·정비·생산직 2      청각장애-중증     12
# 24966 인쇄·목재·공예 및 기타 설치·정비·생산직 4      청각장애-중증     12
# 24967 인쇄·목재·공예 및 기타 설치·정비·생산직 4      청각장애-중증     12
# 24968 경영·행정·사무직                        1      지체장애-경증     11
# 24969 제조 단순직                             2      지적장애-중증      8
# 24970 제조 단순직                             1      지적장애-중증      8
# 24971 교육직                                  2      지체장애-경증     12
# 24972 돌봄 서비스직(간병·육아)                5      지체장애-경증     11
# 24973 기계 설치·정비·생산직                   3      지체장애-경증     11
# 24974 청소 및 기타 개인서비스직               2      지적장애-중증      6
# 24975 제조 단순직                             2      정신장애-중증     12
# 24976 경영·행정·사무직                        5      시각장애-경증     10
# 24977 돌봄 서비스직(간병·육아)                4      지체장애-경증     12
# 24978 영업·판매직                             4      시각장애-경증     12
# 24979 음식 서비스직                           1      청각장애-경증     12
#       근무지역분류
# 1     경북
# 2     경북
# 3     경북
# 4     경북
# 5     경북
# 6     경북
# 7     경북
# 8     경북
# 9     강원
# 10    강원
# 11    강원
# 12    강원
# 13    강원
# 14    강원
# 15    강원
# 16    강원
# 17    강원
# 18    강원
# 19    강원
# 20    전남
# 21    전남
# 22    충북
# 23    충북
# 24    충북
# 25    충북
# 26    충북
# 27    충북
# 28    충북
# 29    충북
# 30    충북
# ⋮     ⋮
# 24950 서울
# 24951 서울
# 24952 서울
# 24953 서울
# 24954 서울
# 24955 충남
# 24956 대구
# 24957 서울
# 24958 전남
# 24959 서울
# 24960 대구
# 24961 대구
# 24962 대구
# 24963 대구
# 24964 대구
# 24965 대구
# 24966 대구
# 24967 대구
# 24968 경기
# 24969 제주
# 24970 제주
# 24971 경기
# 24972 충남
# 24973 충남
# 24974 광주
# 24975 경기
# 24976 경기
# 24977 충남
# 24978 서울
# 24979 서울

# %%
data$취업직종_중증여부 <- paste(data$취업직종대분류,"-",data$중증여부)

# %%
table(data$취업직종_중증여부)
# Out:
#                             건설·채굴직 - 경증
#                                             95
#                             건설·채굴직 - 중증
#                                             39
#                        경영·행정·사무직 - 경증
#                                           3463
#                        경영·행정·사무직 - 중증
#                                           5498
#                             경호·경비직 - 경증
#                                            653
#                             경호·경비직 - 중증
#                                            226
#                     관리직(임원·부서장) - 경증
#                                             91
#                     관리직(임원·부서장) - 중증
#                                             84
#                                  교육직 - 경증
#                                             79
#                                  교육직 - 중증
#                                             95
#                   기계 설치·정비·생산직 - 경증
#                                             86
#                   기계 설치·정비·생산직 - 중증
#                                            157
#                돌봄 서비스직(간병·육아) - 경증
#                                            149
#                돌봄 서비스직(간병·육아) - 중증
#                                            303
#                      미용·예식 서비스직 - 경증
#                                            214
#                      미용·예식 서비스직 - 중증
#                                             52
#                             보건·의료직 - 경증
#                                            266
#                             보건·의료직 - 중증
#                                           1343
#                         사회복지·종교직 - 경증
#                                             97
#                         사회복지·종교직 - 중증
#                                            133
#                        섬유·의복 생산직 - 경증
#                                             42
#                        섬유·의복 생산직 - 중증
#                                            140
#                   스포츠·레크리에이션직 - 경증
#                                             35
#                   스포츠·레크리에이션직 - 중증
#                                            304
#                        식품 가공·생산직 - 경증
#                                             45
#                        식품 가공·생산직 - 중증
#                                            231
#                             영업·판매직 - 경증
#                                            211
#                             영업·판매직 - 중증
#                                            449
#                      예술·디자인·방송직 - 경증
#                                             31
#                      예술·디자인·방송직 - 중증
#                                            104
#                             운전·운송직 - 경증
#                                            194
#                             운전·운송직 - 중증
#                                            155
#                           음식 서비스직 - 경증
#                                            133
#                           음식 서비스직 - 중증
#                                            982
# 인쇄·목재·공예 및 기타 설치·정비·생산직 - 경증
#                                            105
# 인쇄·목재·공예 및 기타 설치·정비·생산직 - 중증
#                                            575
#              전기·전자 설치·정비·생산직 - 경증
#                                            108
#              전기·전자 설치·정비·생산직 - 중증
#                                            253
#                             제조 단순직 - 경증
#                                            417
#                             제조 단순직 - 중증
#                                           2057
#               청소 및 기타 개인서비스직 - 경증
#                                           1881
#               청소 및 기타 개인서비스직 - 중증
#                                           3404

# %%
unique(data$취업직종_중증여부)
# Out:
#  [1] "경영·행정·사무직 - 중증"
#  [2] "경영·행정·사무직 - 경증"
#  [3] "보건·의료직 - 중증"
#  [4] "보건·의료직 - 경증"
#  [5] "전기·전자 설치·정비·생산직 - 중증"
#  [6] "사회복지·종교직 - 경증"
#  [7] "사회복지·종교직 - 중증"
#  [8] "청소 및 기타 개인서비스직 - 경증"
#  [9] "청소 및 기타 개인서비스직 - 중증"
# [10] "돌봄 서비스직(간병·육아) - 경증"
# [11] "돌봄 서비스직(간병·육아) - 중증"
# [12] "음식 서비스직 - 중증"
# [13] "스포츠·레크리에이션직 - 중증"
# [14] "경호·경비직 - 경증"
# [15] "운전·운송직 - 경증"
# [16] "제조 단순직 - 중증"
# [17] "전기·전자 설치·정비·생산직 - 경증"
# [18] "예술·디자인·방송직 - 경증"
# [19] "제조 단순직 - 경증"
# [20] "인쇄·목재·공예 및 기타 설치·정비·생산직 - 중증"
# [21] "교육직 - 중증"
# [22] "예술·디자인·방송직 - 중증"
# [23] "영업·판매직 - 경증"
# [24] "스포츠·레크리에이션직 - 경증"
# [25] "영업·판매직 - 중증"
# [26] "섬유·의복 생산직 - 중증"
# [27] "운전·운송직 - 중증"
# [28] "인쇄·목재·공예 및 기타 설치·정비·생산직 - 경증"
# [29] "식품 가공·생산직 - 중증"
# [30] "기계 설치·정비·생산직 - 경증"
# [31] "경호·경비직 - 중증"
# [32] "건설·채굴직 - 경증"
# [33] "음식 서비스직 - 경증"
# [34] "관리직(임원·부서장) - 경증"
# [35] "섬유·의복 생산직 - 경증"
# [36] "관리직(임원·부서장) - 중증"
# [37] "기계 설치·정비·생산직 - 중증"
# [38] "건설·채굴직 - 중증"
# [39] "교육직 - 경증"
# [40] "미용·예식 서비스직 - 중증"
# [41] "미용·예식 서비스직 - 경증"
# [42] "식품 가공·생산직 - 경증"

# %%
data$근무지역분류 <- as.character(data$근무지역분류)
data$근무지역분류 <- factor(data$근무지역분류)
data$장애유형 <- as.character(data$장애유형)
data$장애유형 <- factor(data$장애유형)
data$중증여부 <- as.character(data$중증여부)
data$중증여부 <- factor(data$중증여부)
data$근무지역 <- as.character(data$근무지역)
data$근무지역 <- factor(data$근무지역)
data$취업직종대분류 <- as.character(data$취업직종대분류)
data$취업직종대분류 <- factor(data$취업직종대분류)
data$연령대 <- as.character(data$연령대)
data$연령대 <- factor(data$연령대)
data$장애유형_중증여부 <- as.character(data$장애유형_중증여부)
data$장애유형_중증여부 <- factor(data$장애유형_중증여부)
data$월 <- as.character(data$월)
data$월 <- factor(data$월)

# %%
# 불필요한 컬럼 제거

data_filtered <- subset(data, select = -c(취업일자,연령,장애유형,중증여부,근무지역))
sum(is.na(data_filtered))
# Out:
# [1] 0

# %%
# 연령대
data_filtered$age_20 <- data_filtered$연령대 == 1
data_filtered$age_30 <- data_filtered$연령대 == 2
data_filtered$age_40 <- data_filtered$연령대 == 3
data_filtered$age_50 <- data_filtered$연령대 == 4
data_filtered$age_60 <- data_filtered$연령대 == 5
data_filtered$age_70 <- data_filtered$연령대 == 6

# %%
# 장애유형_중증여부 바꾸기
data_filtered$시각장애_중증 <- data_filtered$장애유형_중증여부 == "시각장애-중증"
data_filtered$시각장애_경증 <- data_filtered$장애유형_중증여부 == "시각장애-경증"

data_filtered$지체장애_중증 <- data_filtered$장애유형_중증여부 == "지체장애-중증"
data_filtered$지체장애_경증 <- data_filtered$장애유형_중증여부 == "지체장애-경증"

data_filtered$지적장애_경증 <- data_filtered$장애유형_중증여부 == "지적장애-경증"
data_filtered$지적장애_중증 <- data_filtered$장애유형_중증여부 == "지적장애-중증"

data_filtered$청각장애_경증 <- data_filtered$장애유형_중증여부 == "청각장애-경증"
data_filtered$청각장애_중증 <- data_filtered$장애유형_중증여부 == "청각장애-중증"

data_filtered$정신장애_경증 <- data_filtered$장애유형_중증여부 == "정신장애-경증"
data_filtered$정신장애_중증 <- data_filtered$장애유형_중증여부 == "정신장애-중증"

# %%
#   근무지역 분류 바꾸기
data_filtered$경북 <- data_filtered$근무지역분류 == "경북"

data_filtered$강원 <- data_filtered$근무지역분류 == "강원"

data_filtered$전남 <- data_filtered$근무지역분류 == "전남"

data_filtered$충북 <- data_filtered$근무지역분류 == "충북"

data_filtered$경기 <- data_filtered$근무지역분류 == "경기"

data_filtered$인천 <- data_filtered$근무지역분류 == "인천"

data_filtered$서울 <- data_filtered$근무지역분류 == "서울"

data_filtered$울산 <- data_filtered$근무지역분류 == "울산"

data_filtered$대전 <- data_filtered$근무지역분류 == "대전"

data_filtered$부산 <- data_filtered$근무지역분류 == "부산"

data_filtered$전북 <- data_filtered$근무지역분류 == "전북"

data_filtered$광주 <- data_filtered$근무지역분류 == "광주"

data_filtered$충남 <- data_filtered$근무지역분류 == "충남"

data_filtered$대구 <- data_filtered$근무지역분류 == "대구"

data_filtered$경남 <- data_filtered$근무지역분류 == "경남"

data_filtered$제주 <- data_filtered$근무지역분류 == "제주"

data_filtered$세종 <- data_filtered$근무지역분류 == "세종"

data_filtered$경북 <- data_filtered$근무지역분류 == "경북"

# %%
# 월
data_filtered$Jan <- data_filtered$월  == 01
data_filtered$Feb <- data_filtered$월  == 02
data_filtered$Mar <- data_filtered$월  == 03
data_filtered$Apr <- data_filtered$월  == 04
data_filtered$May <- data_filtered$월  == 05
data_filtered$Jun <- data_filtered$월  == 06
data_filtered$Jul <- data_filtered$월  == 07
data_filtered$Aug <- data_filtered$월  == 08
data_filtered$Sep <- data_filtered$월  == 09
data_filtered$Oct <- data_filtered$월  == 10
data_filtered$Nov <- data_filtered$월  == 11
data_filtered$Dec <- data_filtered$월  == 12

# %%
# 불필요한 컬럼 제거
data_filtered_subset <- subset(data_filtered, select = -c(연령대,장애유형_중증여부,월,근무지역분류))

# %% [markdown]
# # 변동사항

# %%
data_filtered_subset$target<-ifelse(data_filtered_subset$취업직종_중증여부 == "섬유·의복 생산직 - 경증", 1, 0)

# %%
data_filtered_subset$target <- factor(data_filtered_subset$target)

# %%
data_filtered_subset <- subset(data_filtered_subset, select = -c(취업직종대분류,취업직종_중증여부))

# %% [markdown]
# # 시험준비

# %%
samp <- createDataPartition(data_filtered_subset$target, p=0.7, list=F)

#   학습용
data.tr <- data_filtered_subset[samp,]

#   검증용
data.test <- data_filtered_subset[-samp,]

# %%
#   KNN을 위한 Training Data 준비
data.training <- subset(data.tr, select = -target)
data.training.label <- data.tr$target

# %%
#   문제 및 정답 만들기
x   <- subset(data.test, select = -target)
y   <- data.test$target

# %% [markdown]
# # 학습시키기

# %%
#  랜덤포레스트 학습 시키기
rf <- randomForest(target ~., data.tr, ntree=100)

# %%
# SVM 학습시키기
modelsvm <- svm(target~.,data.tr)

# %%
# KNN 학습시키기 3,5,7,
knnmodel <- knn(train=data.training, test=x,cl=data.training.label,k=3)

# %%
# nnet 학습시키기
modelnnet <- nnet(target~.,data.tr,size =10)
# Out:
# # weights:  471
# initial  value 33934.772666
# final  value 5526.204223
# converged

# %% [markdown]
# # 검증하기

# %%
#  Random Forest 검증하기
predrf <- predict(rf, x)

# %%
#  SVM 검증하기
predmodelsvm <- predict(modelsvm, x)

# %%
# KNN 검증하기
mean(knnmodel==y)
# Out:
# [1] 0.9983985

# %%
# nnet 검증하기
prednnet = predict(modelnnet, x,type = "class")    # class : 객관식, raw : 주관식

# %% [markdown]
# # 예측력 확인

# %%
#  RF 예측력
mean(predrf == y)
# Out:
# [1] 0.9983985

# %%
#  SVM 예측력
mean(predmodelsvm == y)
# Out:
# [1] 0.9983985

# %%
#  SVM 예측력
mean(knnmodel == y)
# Out:
# [1] 0.9983985

# %%
#  nnet 예측력
mean(prednnet == y)
# Out:
# [1] 0.9983985

# %% [markdown]
# # 오분류표

# %%
#  Random Forest 오분류표
table(predrf,y)
# Out:
#       y
# predrf    0    1
#      0 7481   12
#      1    0    0

# %%
#  SVM 오분류표
table(predmodelsvm,y)
# Out:
#             y
# predmodelsvm    0    1
#            0 7481   12
#            1    0    0

# %%
#  KNN 오분류표
table(y, knnmodel)
# Out:
#    knnmodel
# y      0    1
#   0 7481    0
#   1   12    0

# %%
# nnet 오분류표
table(prednnet,y)
# Out:
#         y
# prednnet    0    1
#        0 7481   12

# %%
# 새로운 데이터에 대한 예측
predict(rf, (list(age_20=FALSE,age_30=FALSE,age_40=FALSE,age_50=FALSE,age_60=TRUE,age_70=FALSE,
            시각장애_중증=TRUE,시각장애_경증=FALSE,지체장애_경증=FALSE,지체장애_중증=FALSE,지적장애_경증=FALSE,지적장애_중증=FALSE,
            청각장애_경증=FALSE,청각장애_중증=FALSE,정신장애_경증=FALSE,정신장애_중증=FALSE,
            경북=TRUE,강원=FALSE,전남=FALSE,충북=FALSE,경기=FALSE,인천=FALSE,서울=FALSE,울산=FALSE,대전=FALSE,부산=FALSE,
            전북=FALSE,광주=FALSE,충남=FALSE,대구=FALSE,경남=FALSE,제주=FALSE,세종=FALSE,경북=FALSE,
            Jan=TRUE,Feb=FALSE,Mar=FALSE,Apr=FALSE,May=FALSE,Jun=FALSE,Jul=FALSE,Aug=FALSE,Sep=FALSE,
            Oct=FALSE,Nov=FALSE,Dec=FALSE)), type = "prob")

# pred_prob <- predict(rf, new_data, type = "prob")
# pred_prob <- predict(rf, new_data, type = "prob")
# Out:
#   0 1
# 1 1 0
